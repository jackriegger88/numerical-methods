# %% [markdown]
# ## Part 1: Numerical Integration
#
# In this part, you will be asked to approximate this integral:
#
# $$
# \int_0^2 x^3 - 2x +4
# $$
# Analytically, the solution to this integral is:
# $$
# \int_0^2 x^3 - 2x +4 = [x^4/4-x^2+4x]_0^2=8
# $$
#
# You will be tasked with writing functions to integrate via the trapezoidal rule or Simpson's rule. You should review [this webpage](https://www.sfu.ca/math-coursenotes/Math%20158%20Course%20Notes/sec_Numerical_Integration.html) (or any texts from previous courses) to recall the mathematical form of these rules.
# A numerical integration approach will always be an approximation, so you should compare your results to the expected value obtained analytically (8).

# %% [markdown]
# ### Exercise 1: Trapezoidal Rule
#
# In the same directory as this notebook, you should find `integration.py`. This is a pure Python file, no Jupyter notebook involved. You should write the function `trapezoidal_rule()` which can then be imported and used, as shown in the cell below.
#
# Compute the integral above using the trapezoidal rule three different times, each time using a different number of slices (10, 100, and 1000). Also compute the fractional error based on the known value from the analytic solution. Make sure all results are printed to output.

# %%
#CLAUDE: here, write a line that will ensure that the module is re-imported everytime the cell is run, otherwise students may get confused
from integration import trapezoidal_rule

# %% [markdown]
# ### Exercise 2: Error Estimation on Trapezoidal Rule
# There is not always a known analytic solution for an integral.
#
# Claude: Introduce Euler-Maclaurin formula and the practical implementation of error estimation when an analytic expression is not known which estimates error by computing the integral twice, the second time with double the steps of the first time.

# %%
# error estimation

# %% [markdown]
# ### Exercise 3: Simpson's Rule
#
# In the same directory as this notebook, you should find `integration.py`. This is a pure Python file, no Jupyter notebook involved. You should write the function `simpsons_rule()` which can then be imported and used, as shown in the cell below.
#
# Compute the integral above using Simpson's rule three different times, each time using a different number of slices (10, 100, and 1000). Also compute the fractional error based on the known value from the analytic solution.

# %%
#CLAUDE: here, write a line that will ensure that the module is re-imported everytime the cell is run, otherwise students may get confused
from integration import simpsons_rule

# %% [markdown]
# ### Exercise 4: Error Estimation on Simpson's Rule
# As with the trapezoidal rule, we can estimate the errors on integrals obtained with Simpson's rule.
#
#
# Claude: Introduce equivalent to the Euler-Maclaurin formula but for Simpson's rule and also the practical implementation of error estimation when an analytic expression is not known which estimates error by computing the integral twice, the second time with double the steps of the first time.

# %% [markdown]
# Claude: Write an essay question about interpretation of integral approximations and their errors

# %% [markdown]
# Claude: briefly introduce the idea that there are other numerical integration algorithms and provide links to learn more about romberg integration and gaussian quadrature. also make note of the Python packages that implement various numerical integration algorithms

# %% [markdown]
# ## Part 2: Gradient Descent
#
# You will not hear much about numerical derivatives because the derivatives of known functions can always be calculated analytically and because both rounding errors and approximation errors for numerical derivatives turn out to be significant.
#
# A much more useful technique to learn about is related to derivatives: gradient descent.
#
# Claude -  go on to introduce more about gradient descent and its usefulness in optimization problems
